# %%
import ROOT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-ee8dc4376aa8> in <module>
# ----> 1 import ROOT
#
# ModuleNotFoundError: No module named 'ROOT'

# %%
# %matplotlib inline
import uproot
import hist
import matplotlib.pyplot as plt
import mplhep as hep
from pathlib import Path

# %%
hep.set_style(hep.styles.CMS)

# %%
# %load_ext watermark
# %watermark
# %watermark --iversions

# %%
output_dir = Path('./plots/')

# %%
root_file = uproot.open('TestGEMCSCSegmentHistograms.root')

# %%
root_file.keys()
# Out:
# ['SimTrack_etaVScharge;1',
#  'SimTrack_etaVStype;1',
#  'ReducedChi2_csc;1',
#  'ReducedChi2_gemcsc;1',
#  'ReducedChi2_odd_gemcsc;1',
#  'ReducedChi2_even_gemcsc;1',
#  'NumGEMRH;1',
#  'NumCSCRH;1',
#  'NumGEMCSCRH;1',
#  'NumGMCSCSeg;1',
#  'SuperS_LPx;1',
#  'SuperS_LPy;1',
#  'SuperS_LPEx;1',
#  'SuperS_LPEy;1',
#  'SuperS_LDx;1',
#  'SuperS_LDy;1',
#  'SuperS_LDEx;1',
#  'SuperS_LDEy;1',
#  'CSCSegm_LPx;1',
#  'CSCSegm_LPy;1',
#  'CSCSegm_LPEx;1',
#  'CSCSegm_LPEy;1',
#  'CSCSegm_LDx;1',
#  'CSCSegm_LDy;1',
#  'CSCSegm_LDEx;1',
#  'CSCSegm_LDEy;1',
#  'SSegm_LDEy_vs_ndof;1',
#  'SSegm_LPEy_vs_ndof;1',
#  'CSCSegm_LDEy_vs_ndof;1',
#  'CSCSegm_LPEy_vs_ndof;1',
#  'SSegm_LDx_expected;1',
#  'SSegm_LDy_expected;1',
#  'SuperS_LDEx_expected;1',
#  'SuperS_LDEy_expected;1',
#  'xGEMCSCRes;1',
#  'xGEMRes;1',
#  'xCSCRes;1',
#  'xGEMRes_even;1',
#  'xCSCRes_even;1',
#  'xGEMRes_odd;1',
#  'xCSCRes_odd;1',
#  'xGEMCSCRes_cscl1;1',
#  'xGEMCSCRes_cscl2;1',
#  'xGEMCSCRes_cscl3;1',
#  'xGEMCSCRes_cscl4;1',
#  'xGEMCSCRes_cscl5;1',
#  'xGEMCSCRes_cscl6;1',
#  'xGEMCSCRes_geml1;1',
#  'xGEMCSCRes_geml2;1',
#  'xGEMCSCPool;1',
#  'xGEMPool;1',
#  'xCSCPool;1',
#  'xGEMPool_even;1',
#  'xCSCPool_even;1',
#  'xGEMPool_odd;1',
#  'xCSCPool_odd;1',
#  'xGEMCSCPool_cscl1;1',
#  'xGEMCSCPool_cscl2;1',
#  'xGEMCSCPool_cscl3;1',
#  'xGEMCSCPool_cscl4;1',
#  'xGEMCSCPool_cscl5;1',
#  'xGEMCSCPool_cscl6;1',
#  'xGEMCSCPool_geml1;1',
#  'xGEMCSCPool_geml2;1',
#  'yGEMCSCRes;1',
#  'yGEMRes;1',
#  'yCSCRes;1',
#  'yGEMRes_even;1',
#  'yCSCRes_even;1',
#  'yGEMRes_odd;1',
#  'yCSCRes_odd;1',
#  'yGEMCSCRes_cscl1;1',
#  'yGEMCSCRes_cscl2;1',
#  'yGEMCSCRes_cscl3;1',
#  'yGEMCSCRes_cscl4;1',
#  'yGEMCSCRes_cscl5;1',
#  'yGEMCSCRes_cscl6;1',
#  'yGEMCSCRes_geml1;1',
#  'yGEMCSCRes_geml2;1',
#  'yGEMCSCPool;1',
#  'yGEMPool;1',
#  'yCSCPool;1',
#  'yGEMPool_even;1',
#  'yCSCPool_even;1',
#  'yGEMPool_odd;1',
#  'yCSCPool_odd;1',
#  'yGEMCSCPool_cscl1;1',
#  'yGEMCSCPool_cscl2;1',
#  'yGEMCSCPool_cscl3;1',
#  'yGEMCSCPool_cscl4;1',
#  'yGEMCSCPool_cscl5;1',
#  'yGEMCSCPool_cscl6;1',
#  'yGEMCSCPool_geml1;1',
#  'yGEMCSCPool_geml2;1',
#  'xGEMPool_newE;1',
#  'yGEMPool_newE;1',
#  'xGEMPool_odd_newE;1',
#  'yGEMPool_odd_newE;1',
#  'xGEMPool_newE_mp;1',
#  'yGEMPool_newE_mp;1',
#  'xGEMPool_odd_newE_mp;1',
#  'yGEMPool_odd_newE_mp;1',
#  'xGEMPool_newE_mm;1',
#  'yGEMPool_newE_mm;1',
#  'xGEMPool_odd_newE_mm;1',
#  'yGEMPool_odd_newE_mm;1',
#  'GEMCSC_SSegm_xe_l1;1',
#  'GEMCSC_SSegm_ye_l1;1',
#  'GEMCSC_SSegm_ze_l1;1',
#  'GEMCSC_SSegm_sigmaxe_l1;1',
#  'GEMCSC_SSegm_sigmaye_l1;1',
#  'GEMCSC_SSegm_xe_l1_odd;1',
#  'GEMCSC_SSegm_ye_l1_odd;1',
#  'GEMCSC_SSegm_ze_l1_odd;1',
#  'GEMCSC_SSegm_sigmaxe_l1_odd;1',
#  'GEMCSC_SSegm_sigmaye_l1_odd;1',
#  'GEMCSC_SSegm_xe_l1_even;1',
#  'GEMCSC_SSegm_ye_l1_even;1',
#  'GEMCSC_SSegm_ze_l1_even;1',
#  'GEMCSC_SSegm_sigmaxe_l1_even;1',
#  'GEMCSC_SSegm_sigmaye_l1_even;1',
#  'GEMCSC_SSegm_xe_l2;1',
#  'GEMCSC_SSegm_ye_l2;1',
#  'GEMCSC_SSegm_ze_l2;1',
#  'GEMCSC_SSegm_sigmaxe_l2;1',
#  'GEMCSC_SSegm_sigmaye_l2;1',
#  'GEMCSC_SSegm_xe_l2_odd;1',
#  'GEMCSC_SSegm_ye_l2_odd;1',
#  'GEMCSC_SSegm_ze_l2_odd;1',
#  'GEMCSC_SSegm_sigmaxe_l2_odd;1',
#  'GEMCSC_SSegm_sigmaye_l2_odd;1',
#  'GEMCSC_SSegm_xe_l2_even;1',
#  'GEMCSC_SSegm_ye_l2_even;1',
#  'GEMCSC_SSegm_ze_l2_even;1',
#  'GEMCSC_SSegm_sigmaxe_l2_even;1',
#  'GEMCSC_SSegm_sigmaye_l2_even;1',
#  'GEMCSC_CSCSegm_xe_l1;1',
#  'GEMCSC_CSCSegm_ye_l1;1',
#  'GEMCSC_CSCSegm_ze_l1;1',
#  'GEMCSC_CSCSegm_sigmaxe_l1;1',
#  'GEMCSC_CSCSegm_sigmaye_l1;1',
#  'GEMCSC_CSCSegm_xe_l1_odd;1',
#  'GEMCSC_CSCSegm_ye_l1_odd;1',
#  'GEMCSC_CSCSegm_ze_l1_odd;1',
#  'GEMCSC_CSCSegm_sigmaxe_l1_odd;1',
#  'GEMCSC_CSCSegm_sigmaye_l1_odd;1',
#  'GEMCSC_CSCSegm_xe_l1_even;1',
#  'GEMCSC_CSCSegm_ye_l1_even;1',
#  'GEMCSC_CSCSegm_ze_l1_even;1',
#  'GEMCSC_CSCSegm_sigmaxe_l1_even;1',
#  'GEMCSC_CSCSegm_sigmaye_l1_even;1',
#  'GEMCSC_CSCSegm_xe_l2;1',
#  'GEMCSC_CSCSegm_ye_l2;1',
#  'GEMCSC_CSCSegm_ze_l2;1',
#  'GEMCSC_CSCSegm_sigmaxe_l2;1',
#  'GEMCSC_CSCSegm_sigmaye_l2;1',
#  'GEMCSC_CSCSegm_xe_l2_odd;1',
#  'GEMCSC_CSCSegm_ye_l2_odd;1',
#  'GEMCSC_CSCSegm_ze_l2_odd;1',
#  'GEMCSC_CSCSegm_sigmaxe_l2_odd;1',
#  'GEMCSC_CSCSegm_sigmaye_l2_odd;1',
#  'GEMCSC_CSCSegm_xe_l2_even;1',
#  'GEMCSC_CSCSegm_ye_l2_even;1',
#  'GEMCSC_CSCSegm_ze_l2_even;1',
#  'GEMCSC_CSCSegm_sigmaxe_l2_even;1',
#  'GEMCSC_CSCSegm_sigmaye_l2_even;1',
#  'Dphi_gemRHgemcscS_min_afterCut;1',
#  'Dtheta_gemRHgemcscS_min_afterCut;1',
#  'Dphi_gemRHgemcscS_min_afterCut_odd;1',
#  'Dphi_gemRHgemcscS_min_afterCut_even;1',
#  'DR_gemRHgemcscS_min_afterCut;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l1;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l1_odd;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l1_even;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l2;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l2_odd;1',
#  'Dphi_gemRHgemcscS_min_afterCut_l2_even;1',
#  'Dphi_gemRHcscS_min_afterCut;1',
#  'Dtheta_gemRHcscS_min_afterCut;1',
#  'Dtheta_gemRHcscS_min_afterCut_odd;1',
#  'Dtheta_gemRHcscS_min_afterCut_even;1',
#  'DR_gemRHcscS_min_afterCut;1',
#  'Dphi_gemRHcscS_min_afterCut_l1;1',
#  'Dphi_gemRHcscS_min_afterCut_l1_odd;1',
#  'Dphi_gemRHcscS_min_afterCut_l1_even;1',
#  'Dphi_gemRHcscS_min_afterCut_l2;1',
#  'Dphi_gemRHcscS_min_afterCut_l2_odd;1',
#  'Dphi_gemRHcscS_min_afterCut_l2_even;1',
#  'Dphi_gemRHcscS_min_afterCut_odd;1',
#  'Dphi_gemRHcscS_min_afterCut_even;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r1;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r2;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r3;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r4;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r5;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r6;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r7;1',
#  'Dphi_gemRHcscS_min_afterCut_odd_r8;1',
#  'Dphi_gemSHSS_min_afterCut;1',
#  'Dtheta_gemSHSS_min_afterCut;1',
#  'Dtheta_gemSHSS_min_afterCut_odd;1',
#  'Dtheta_gemSHSS_min_afterCut_even;1',
#  'Dphi_gemSHSS_min_afterCut_odd;1',
#  'Dphi_gemSHSS_min_afterCut_even;1',
#  'Dphi_gemSHcscS_min_afterCut;1',
#  'Dtheta_gemSHcscS_min_afterCut;1',
#  'Dtheta_gemSHcscS_min_afterCut_odd;1',
#  'Dtheta_gemSHcscS_min_afterCut_even;1',
#  'Dphi_gemSHcscS_min_afterCut_odd;1',
#  'Dphi_gemSHcscS_min_afterCut_even;1',
#  'xGEMRes_simhit;1',
#  'yGEMRes_simhit;1',
#  'xGEMPool_newE_simhit;1',
#  'yGEMPool_newE_simhit;1',
#  'xGEMRes_odd_simhit;1',
#  'yGEMRes_odd_simhit;1',
#  'xGEMPool_odd_newE_simhit;1',
#  'yGEMPool_odd_newE_simhit;1',
#  'xGEMRes_even_simhit;1',
#  'yGEMRes_even_simhit;1',
#  'xGEMPool_even_newE_simhit;1',
#  'yGEMPool_even_newE_simhit;1',
#  'xGEMRes_shrh;1',
#  'yGEMRes_shrh;1',
#  'xGEMPool_shrh;1',
#  'yGEMPool_shrh;1',
#  'SIMGEMCSCSegm_theta_cscSsh_vs_ndof_odd;1',
#  'SIMGEMCSCSegm_theta_cscSsh_vs_ndof_even;1']

# %%
def plot(key, ax=None, label=None):
    h = root_file[key].to_hist()
    if ax is None:
        fig, ax = plt.subplots()
    else:
        fig = None
    h.plot(ax=ax, label=label)
    ax.set_title('2021 (14 TeV)', loc='right')
    ax.legend(title='1k ZMM')
    if ax is not None:
        return fig, ax

# %%
key = 'NumGEMRH'
fig, ax = plot(key)
ax.set_xlim(0, 4)
ax.set_xlabel('Number of GEMRecHits in GEMCSCSegments')
ax.set_ylabel('Number of GEMCSCSegments')
fig.savefig(output_dir.joinpath(key).with_suffix('.png'))
fig.savefig(output_dir.joinpath(key).with_suffix('.pdf'))
# Out:
# No handles with labels found to put in legend.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
key = 'NumCSCRH'
fig, ax = plot(key)
ax.set_xlim(2, 8)
ax.set_xlabel('Number of CSCRecHits in GEMCSCSegments')
ax.set_ylabel('Number of GEMCSCSegments')
fig.savefig(output_dir.joinpath(key).with_suffix('.png'))
fig.savefig(output_dir.joinpath(key).with_suffix('.pdf'))
# Out:
# No handles with labels found to put in legend.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
key = 'NumGEMCSCRH'
fig, ax = plot(key)
ax.set_xlim(3, 10)
ax.set_xlabel('Number of GEM & CSC RecHits in GEMCSCSegments')
ax.set_ylabel('Number of GEMCSCSegments')
fig.savefig(output_dir.joinpath(key).with_suffix('.png'))
fig.savefig(output_dir.joinpath(key).with_suffix('.pdf'))
# Out:
# No handles with labels found to put in legend.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
key = 'NumGMCSCSeg'
fig, ax = plot(key)
ax.set_xlabel('Number of GEMCSCSegments per event')
ax.set_ylabel('Number of Events')
fig.savefig(output_dir.joinpath(key).with_suffix('.png'))
fig.savefig(output_dir.joinpath(key).with_suffix('.pdf'))
# Out:
# No handles with labels found to put in legend.
# 'texgyreheros-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %%
h = root_file['NumGMCSCSeg'].to_hist()

# %%
h.to_numpy()[0].sum()
# Out:
# 707.0

# %%
fig, ax = plot('ReducedChi2_gemcsc', label='CSCSegment')
plot('ReducedChi2_csc', ax=ax, label='GEMCSCSegment')
# Out:
# (None, <AxesSubplot:title={'right':'2021 (14 TeV)'}>)
